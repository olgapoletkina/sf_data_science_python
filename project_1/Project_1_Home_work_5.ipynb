# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
df = pd.read_csv('/content/drive/MyDrive/MFTI/Python/Skillfactory/Final_project_1_sem/dst-3.0_16_1_hh_database.csv', sep=';')
df.shape
# Out:
# (44744, 12)

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
print('Пять первых строк в таблице:')
display(df.head())
print('-'*200)
print('Пять последних строк в таблице:')
display(df.tail())
# Out:
# Пять первых строк в таблице:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
df.isna().sum()
# Out:
# Пол, возраст                         0
# ЗП                                   0
# Ищет работу на должность:            0
# Город, переезд, командировки         0
# Занятость                            0
# График                               0
# Опыт работы                        168
# Последнее/нынешнее место работы      1
# Последняя/нынешняя должность         2
# Образование и ВУЗ                    0
# Обновление резюме                    0
# Авто                                 0
# dtype: int64

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
df.describe()
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
df['Образование'] = df['Образование и ВУЗ'].apply(lambda raw_education: raw_education.partition(' образование')[0]).astype('category')
display(df['Образование'].value_counts())
df.drop(['Образование и ВУЗ'], axis=1, inplace=True)
# Out:
# Образование
# Высшее                 33863
# Среднее специальное     5765
# Неоконченное высшее     4557
# Среднее                  559
# Name: count, dtype: int64

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
df['Пол'] = df['Пол, возраст'].apply(lambda x: x.split(', ')[0])
df['Пол'] = df['Пол'].apply(lambda x: 'Ж' if 'Жен' in x else 'М')

df['Возраст'] = df['Пол, возраст'].apply(lambda x: int(x.split(', ')[1].split(' ')[1]))

print(f'Всего женских резюме: {round(len(df[df["Пол"] == "Ж"]) / len(df) * 100, 2)} %')
print(f'Средний возраст соискателей: {round(df["Возраст"].mean(), 1)}')

df.drop('Пол, возраст', axis=1, inplace=True)
# Out:
# Всего женских резюме: 19.07 %
# Средний возраст соискателей: 32.2

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
def experience(exp):
    if pd.isnull(exp) or exp == 'Не указано':
        return np.nan
    else:
        splitted_data = exp[len('Опыт работы '):].split()
        if splitted_data[1] in ['год', 'года', 'лет']:
            months = int(splitted_data[0])*12
            if splitted_data[2].isdigit():
                return months + int(splitted_data[2])
            else:
                return months
        else:
            return int(splitted_data[0])

df['Опыт работы (месяц)'] = df['Опыт работы'].apply(experience)
df.drop(['Опыт работы'], axis=1, inplace=True)
median_exp = df['Опыт работы (месяц)'].median()
print(f'Медианный опыт работы: {median_exp}')
# Out:
# Медианный опыт работы: 100.0

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 'Челябинск', 'Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград']

def city(city_line):
    city = city_line.split(',')[0].strip()
    if city in ['Москва', 'Санкт-Петербург']:
        return city
    elif city in million_cities:
        return 'город-миллионник'
    else:
        return 'другие'

def relocation(city_line):
    if 'не готова к переезду' in city_line or 'не готов к переезду' in city_line:
        return False
    else:
        return True

def trips(city_line):
    sections = city_line.split(',')
    readiness = [sec for sec in sections if 'командировка' in sec]
    if len(readiness) == 0:
        return False
    else:
        return not('не' in readiness[0] or 'Не' in readiness[0])


df['Город'] = df['Город, переезд, командировки'].apply(city).astype('category')
df['Готовность к переезду'] = df['Город, переезд, командировки'].apply(relocation)
df['Готовность к командировкам'] = df['Город, переезд, командировки'].apply(trips)
df.drop(['Город, переезд, командировки'], axis=1, inplace=True)

in_spb = round(df['Город'].value_counts(normalize=True)['Санкт-Петербург']*100)
print(f'{in_spb}% соискателей в Санкт-Петербурге')
ready_relocate_and_trip = df[df['Готовность к переезду'] & df['Готовность к командировкам']].shape[0]
print(f'Готовы к переездам и командировкам {round((ready_relocate_and_trip/df.shape[0])*100)}% соискателей')
# Out:
# 11% соискателей в Санкт-Петербурге
# Готовы к переездам и командировкам 32% соискателей

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
for item in df['Занятость'].apply(lambda x: x.split(', ')).explode().unique():
    df[item] = df['Занятость'].apply(lambda x: True if item in x else False)

for item in df['График'].apply(lambda x: x.split(', ')).explode().unique():
    df[item] = df['График'].apply(lambda x: True if item in x else False)

print(len(df[(df['проектная работа'] == True) &  (df['волонтерство'] == True)]), 'людей ищут проектную работу и волонтёрство')
print(len(df[(df['вахтовый метод'] == True) &  (df['гибкий график'] == True)]), 'людей хотят работать вахтовым методом и с гибким графиком')

df.drop(['Занятость', 'График'], axis=1, inplace=True)
# Out:
# 436 людей ищут проектную работу и волонтёрство
# 2311 людей хотят работать вахтовым методом и с гибким графиком

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
import warnings
warnings.filterwarnings("ignore")

currencies_df = pd.read_csv('/content/drive/MyDrive/MFTI/Python/Skillfactory/Final_project_1_sem/ExchangeRates.csv', usecols=['currency', 'date', 'close', 'proportion'])
currencies_df['date'] = pd.to_datetime(currencies_df['date'])
currency_mapping = {
    'грн.': 'UAH',
    'бел.руб.': 'BYN',
    'сум': 'UZS'
    }

def extranct_currency(salary_line):
    currency = salary_line.split(' ')[1].strip()
    return currency_mapping.get(currency, currency)

df['Обновление резюме'] = pd.to_datetime(df['Обновление резюме']).dt.date.astype('datetime64[ns]')
df['salary_sum'] = df['ЗП'].apply(lambda x: x.split(' ')[0]).astype('int32')
df['salary_n_r'] = df['ЗП'].apply(extranct_currency)

df = df.merge(currencies_df, left_on=['salary_n_r', 'Обновление резюме'], right_on=['currency', 'date'], how='left')
df.fillna({'close':1, 'proportion':1}, inplace=True)

df['ЗП (руб)'] = df['salary_sum'] * df['close'] / df['proportion']

df.drop(['ЗП', 'salary_sum', 'salary_n_r', 'currency', 'date', 'close', 'proportion'], axis=1, inplace=True)
salary_median = round(df['ЗП (руб)'].median())
print(f'Желаемая медианная зарплата: {salary_median}')
# Out:
# Желаемая медианная зарплата: 59000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ищет работу на должность:        44744 non-null  object
#  1   Последнее/нынешнее место работы  44743 non-null  object
#  2   Последняя/нынешняя должность     44742 non-null  object
#  3   Обновление резюме                44744 non-null  datetime64[ns]
#  4   Авто                             44744 non-null  object
#  5   Образование                      44744 non-null  category
#  6   Пол                              44744 non-null  object
#  7   Возраст                          44744 non-null  int64
#  8   Опыт работы (месяц)              44574 non-null  float64
#  9   Город                            44744 non-null  category
#  10  Готовность к переезду            44744 non-null  bool
# ...

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig, axes = plt.subplots(2, 1, figsize=(14, 6))

axes[0].hist(df['Возраст'], bins=30, edgecolor='black', alpha=0.7)
axes[0].set_title('Распределение возраста (гистограмма)')
axes[0].set_xlabel('Возраст')
axes[0].set_ylabel('Частота')

axes[1].boxplot(df['Возраст'], vert=False)
axes[1].set_title('Распределение возраста (коробчатая диаграмма)')
axes[1].set_xlabel('Возраст')

plt.tight_layout()
plt.show()

age_mode = df['Возраст'].mode()[0]
age_min = df['Возраст'].min()
age_max = df['Возраст'].max()
age_interval = df['Возраст'].quantile([0.25, 0.75])

print(f'Мода распределения: {age_mode}')
print(f'Предельные значения признака: Минимум = {age_min}, Максимум = {age_max}')
print('Интервал возраста большинства соискателей (межквартильный диапазон):')
print(f'  25-й процентиль: {age_interval[0.25]}')
print(f'  75-й процентиль: {age_interval[0.75]}')
# Out:
# Мода распределения: 30
# Предельные значения признака: Минимум = 14, Максимум = 100
# Интервал возраста большинства соискателей (межквартильный диапазон):
#   25-й процентиль: 27.0
#   75-й процентиль: 36.0

# %% [markdown]
# ### Вывод по "Возраст":
#
# Большинство соискателей находятся в возрастном диапазоне от 27 до 36 лет, а мода составляет 30 лет. Аномальными можно считать значения ниже 14 и выше 75 лет, так как они выходят за границы нормального распределения.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig, axes = plt.subplots(2, 1, figsize=(14, 6))

axes[0].hist(df['Опыт работы (месяц)'], bins=30, edgecolor='black', alpha=0.7)
axes[0].set_title('Распределение опыта работы (гистограмма)')
axes[0].set_xlabel('Опыт работы (месяц)')
axes[0].set_ylabel('Частота')

axes[1].boxplot(df['Опыт работы (месяц)'].dropna(), vert=False)
axes[1].set_title('Распределение опыта работы (коробчатая диаграмма)')
axes[1].set_xlabel('Опыт работы (месяц)')

plt.tight_layout()
plt.show()

experience_mode = df['Опыт работы (месяц)'].mode()[0]
experience_min = df['Опыт работы (месяц)'].min()
experience_max = df['Опыт работы (месяц)'].max()
experience_interval = df['Опыт работы (месяц)'].quantile([0.25, 0.75])

print(f'Мода распределения: {experience_mode}')
print(f'Предельные значения признака: Минимум = {experience_min}, Максимум = {experience_max}')
print('Интервал опыта работы большинства соискателей (межквартильный диапазон):')
print(f'  25-й процентиль: {experience_interval[0.25]}')
print(f'  75-й процентиль: {experience_interval[0.75]}')
# Out:
# Мода распределения: 81.0
# Предельные значения признака: Минимум = 1.0, Максимум = 1188.0
# Интервал опыта работы большинства соискателей (межквартильный диапазон):
#   25-й процентиль: 57.0
#   75-й процентиль: 154.0

# %% [markdown]
# ### Вывод по "Опыт работы (месяц)":
# Большинство соискателей имеют опыт работы в диапазоне от 57 до 154 месяцев, а мода составляет 81 месяц. Аномальные значения встречаются в виде экстремально высокого опыта работы, превышающего 1188 месяцев, что соответствует более 99 лет и, вероятно, является ошибкой ввода.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig, axes = plt.subplots(2, 1, figsize=(14, 6))

axes[0].hist(df['ЗП (руб)'], bins=30, edgecolor='black', alpha=0.7)
axes[0].set_title('Распределение заработной платы (гистограмма)')
axes[0].set_xlabel('Заработная плата (руб)')
axes[0].set_ylabel('Частота')

axes[1].boxplot(df['ЗП (руб)'].dropna(), vert=False)
axes[1].set_title('Распределение заработной платы (коробчатая диаграмма)')
axes[1].set_xlabel('Заработная плата (руб)')

plt.tight_layout()
plt.show()

salary_mode = df['ЗП (руб)'].mode()[0]
salary_min = df['ЗП (руб)'].min()
salary_max = df['ЗП (руб)'].max()
salary_interval = df['ЗП (руб)'].quantile([0.25, 0.75])

print(f'Мода распределения: {salary_mode}')
print(f'Предельные значения признака: Минимум = {salary_min}, Максимум = {salary_max}')
print('Интервал заработной платы большинства соискателей (межквартильный диапазон):')
print(f'  25-й процентиль: {salary_interval[0.25]}')
print(f'  75-й процентиль: {salary_interval[0.75]}')

above_one_million = df[df['ЗП (руб)'] > 1_000_000].shape[0]
print(f'ЗП больше миллиона требует: {above_one_million} человек')
# Out:
# Мода распределения: 50000.0
# Предельные значения признака: Минимум = 1.0, Максимум = 24304876.0
# Интервал заработной платы большинства соискателей (межквартильный диапазон):
#   25-й процентиль: 37082.2
#   75-й процентиль: 95000.0
# ЗП больше миллиона требует: 5 человек

# %% [markdown]
# ### Вывод по "ЗП (руб)":
#
# Большинство соискателей указывают желаемую заработную плату в диапазоне от 37,082 до 95,000 руб., при этом мода составляет 50,000 руб. Аномальные значения встречаются в виде заработных плат выше 1 миллиона руб., что характерно для небольшой группы (5 человек).

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
filtered_df = df[df['ЗП (руб)'] < 1_000_000]

median_salary_by_education = filtered_df.groupby('Образование')['ЗП (руб)'].median().sort_values()

plt.figure(figsize=(10, 6))
median_salary_by_education.plot(kind='bar', color='skyblue', edgecolor='black')

plt.title('Зависимость медианной заработной платы от уровня образования')
plt.xlabel('Уровень образования')
plt.ylabel('Медианная зарплата (руб)')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

print('')
print('-' * 200)
print('Ожидание медианной заработной платы от уровня образования в таблице')
median_salary_by_education
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Ожидание медианной заработной платы от уровня образования в таблице
# Образование
# Среднее                40000.0
# Среднее специальное    40000.0
# Неоконченное высшее    50000.0
# Высшее                 60000.0
# Name: ЗП (руб), dtype: float64

# %% [markdown]
# ### Вывод по ("ЗП (руб)") от уровня образования ("Образование"):
# Наибольшие уровни желаемой заработной платы наблюдаются у соискателей с высшим образованием (60,000 руб.), а наименьшие — у соискателей со средним или средним специальным образованием (40,000 руб.). Признак уровня образования важен для прогнозирования заработной платы, так как уровень образования явно коррелирует с ожидаемым доходом.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
average_salary_by_city = filtered_df.groupby('Город')['ЗП (руб)'].mean().sort_values()

plt.figure(figsize=(10, 6))
average_salary_by_city.plot(kind='bar', color='skyblue', edgecolor='black')

plt.title('Средняя заработная плата (руб) по городам для зарплат менее 1 млн руб')
plt.xlabel('Город')
plt.ylabel('Средняя заработная плата (руб)')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()
print('-'*200)
max_salary_row = df[df['ЗП (руб)'] == df['ЗП (руб)'].max()]
city_with_max_salary = max_salary_row['Город'].values[0]
print(f'В городе (категории городов) "{city_with_max_salary}" зафиксирован наибольший показатель желаемой заработной платы')
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# В городе (категории городов) "другие" зафиксирован наибольший показатель желаемой заработной платы

# %% [markdown]
# ### Вывод по ("ЗП (руб)") в зависимости от города ("Город"):
# Признак города является важным при прогнозировании заработной платы, так как Москва демонстрирует значительно более высокий уровень средней желаемой зарплаты, чем другие города, что отражает существенные региональные различия.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
median_salary_grouped = df.groupby(['Готовность к переезду', 'Готовность к командировкам'])['ЗП (руб)'].median().unstack()

plt.figure(figsize=(10, 6))
median_salary_grouped.plot(kind='bar', figsize=(10, 6), color=['skyblue', 'orange'], edgecolor='black')

plt.title('Медианная заработная плата (руб) в зависимости от готовности к переезду и командировкам')
plt.xlabel('Готовность к переезду')
plt.ylabel('Медианная заработная плата (руб)')
plt.xticks(rotation=0)
plt.legend(title='Готовность к командировкам', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Вывод по ("ЗП (руб)") от признаков "Готовность к переезду" и "Готовность к командировкам":
# Готовность к переезду и командировкам коррелирует с более высокой медианной заработной платой: соискатели, готовые к переезду и командировкам, ожидают заработную плату на уровне около 60,000 руб. Таким образом, гибкость в географии работы и командировках является важным фактором для увеличения уровня желаемой зарплаты.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
pivot_table = df.pivot_table(
    values='ЗП (руб)',
    index='Возраст',
    columns='Образование',
    aggfunc='median'
)

plt.figure(figsize=(10, 6))
sns.heatmap(
    pivot_table,
    cmap='YlGnBu',
    annot=False,
    fmt=".0f",
    cbar_kws={'label': 'Медианная ЗП (руб)'}
)

plt.title('Тепловая карта зависимости медианной заработной платы от возраста и образования')
plt.xlabel('Образование')
plt.ylabel('Возраст')

plt.tight_layout()
plt.show()

pivot_table
# Out:
# Образование     Высшее  Неоконченное высшее  Среднее  Среднее специальное
# Возраст
# 14            60000.00                  NaN      NaN                  NaN
# 15                 NaN                  NaN  10000.0               2000.0
# 16           122582.49                  NaN      NaN              30000.0
# 17            90075.50              80000.0  44000.0              25000.0
# 18            30000.00              25000.0  35000.0              25151.0
# ...                ...                  ...      ...                  ...
# 72            75000.00                  NaN      NaN                  NaN
# 73            62500.00                  NaN      NaN                  NaN
# 76            45000.00                  NaN      NaN                  NaN
# 77            90000.00                  NaN      NaN                  NaN
# 100                NaN                  NaN      NaN              60000.0
#
# [63 rows x 4 columns]

# %% [markdown]
# ### Вывод по  медианной желаемой заработной платы от возраста ("Возраст") и образования ("Образование"):
#
# Тепловая карта показывает, что уровень образования оказывает значительное влияние на желаемую заработную плату: соискатели с высшим образованием в среднем указывают более высокие зарплаты. Возраст также играет роль, при этом более высокие зарплаты чаще запрашивают соискатели среднего возраста (30–50 лет). Соискатели с более низким уровнем образования и моложе 25 лет ожидают заметно меньшую оплату труда.

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
df['Опыт работы (год)'] = df['Опыт работы (месяц)'] / 12
fig, ax = plt.subplots(figsize=(10, 6))
p1 = sns.scatterplot(data=df, x='Возраст', y='Опыт работы (год)', ax=ax)
p2 = sns.lineplot(x=np.linspace(0, 100, 100), y=np.linspace(0, 100, 100), color='r', ax=ax)
ax.set_title('Зависимость опыта от возраста')
df.drop(['Опыт работы (год)'], axis=1, inplace=True)

# %% [markdown]
# ### Вывод по диаграмме рассеяния:
# На графике видно, что большинство соискателей имеют опыт работы, не превышающий их возраст, что логично. Однако присутствуют аномалии — точки выше красной линии, где опыт работы равен или превышает возраст, что может быть связано с ошибками ввода данных.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %% [markdown]
# **Готовность к переезду по категориям городов**

# %%
relocation_readiness = df.groupby(['Город', 'Готовность к переезду']).size().unstack()

relocation_readiness.plot(kind='bar', figsize=(12, 6), color=['skyblue', 'orange'], edgecolor='black')

plt.title('Готовность к переезду по категориям городов')
plt.xlabel('Категория города')
plt.ylabel('Количество соискателей')
plt.xticks(rotation=0)
plt.legend(title='Готовность к переезду', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Вывод по готовности переезда в зависимоости от города:
#
# На графике видно, что соискатели из Москвы чаще готовы к переезду по сравнению с другими категориями городов, причем количество таких соискателей значительно превышает тех, кто не готов к переезду. В других категориях, включая Санкт-Петербург, города-миллионники и "другие", доля готовых к переезду более сбалансирована, с примерно равным распределением между готовыми и не готовыми к переезду.

# %% [markdown]
# **Распределение уровня образования по категориям городов**

# %%
education_by_city = df.groupby(['Город', 'Образование']).size().unstack()

education_by_city.plot(kind='bar', figsize=(12, 6), stacked=True, colormap='viridis', edgecolor='black')

plt.title('Распределение уровня образования по категориям городов')
plt.xlabel('Категория города')
plt.ylabel('Количество соискателей')
plt.xticks(rotation=0)
plt.legend(title='Уровень образования', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

education_by_city_percentage = df.groupby(['Город', 'Образование']).size().unstack()
education_by_city_percentage = education_by_city_percentage.div(education_by_city_percentage.sum(axis=1), axis=0) * 100

education_by_city_percentage
# Out:
# Образование          Высшее  Неоконченное высшее   Среднее  \
# Город
# Москва            79.676313            10.468684  1.131099
# Санкт-Петербург   74.437918            11.849301  1.316589
# город-миллионник  73.499727            10.420076  1.295690
# другие            72.890122             9.259493  1.330894
#
# Образование       Среднее специальное
# Город
# Москва                       8.723903
# Санкт-Петербург             12.396192
# город-миллионник            14.784506
# другие                      16.519490

# %% [markdown]
# ### Вывод по распределению уровня образования в городах:
# На графике и в таблице видно, что в большинстве категорий городов преобладают соискатели с высшим образованием, особенно в Москве, где доля таких соискателей составляет почти 80%. В Санкт-Петербурге и городах-миллионниках также значителен процент соискателей с высшим образованием, но немного выше доля кандидатов с неоконченным высшим или средним специальным образованием. Это отражает высокий уровень квалификации среди городских соискателей.

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
print(f'Количество дубликатов: {df.duplicated().sum()}')
df.drop_duplicates(inplace=True)
# Out:
# Количество дубликатов: 161

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
df.isnull().sum()
# Out:
# Ищет работу на должность:            0
# Последнее/нынешнее место работы      1
# Последняя/нынешняя должность         2
# Обновление резюме                    0
# Авто                                 0
# Образование                          0
# Пол                                  0
# Возраст                              0
# Опыт работы (месяц)                168
# Город                                0
# Готовность к переезду                0
# Готовность к командировкам           0
# частичная занятость                  0
# проектная работа                     0
# полная занятость                     0
# стажировка                           0
# волонтерство                         0
# гибкий график                        0
# полный день                          0
# сменный график                       0
# вахтовый метод                       0
# удаленная работа                     0
# ЗП (руб)                             0
# dtype: int64

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
df.fillna({'Опыт работы (месяц)': df['Опыт работы (месяц)'].median()}, inplace=True)
df.dropna(how='any', axis=0, inplace=True)
mean_exp_new = round(df['Опыт работы (месяц)'].mean())
print(f'После удаления среднее значенив Опыте работы (месяц): {mean_exp_new}')
# Out:
# После удаления среднее значенив Опыте работы (месяц): 114

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
salary_outliers = df[(df['ЗП (руб)'] < 1000) | (df['ЗП (руб)'] > 1000000)]
print(f'Всего выбросов по зарплате: {salary_outliers.shape[0]}')
df.drop(salary_outliers.index, inplace=True)
# Out:
# Всего выбросов по зарплате: 89

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
experiance_outliers = df[df['Опыт работы (месяц)']/12 > df['Возраст']]
print(f'Резюме где опыт больше возраста: {experiance_outliers.shape[0]}')
df.drop(experiance_outliers.index, inplace=True)
# Out:
# Резюме где опыт больше возраста: 7

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
plt.figure(figsize=(10, 6))

log_age = [np.log(x) for x in df['Возраст'].values]
log_hist = sns.histplot(log_age, bins=30)

log_mean = np.mean(log_age)
log_std = np.log(df['Возраст']).std()
lower_bound = log_mean - 3 * log_std
upper_bound = log_mean + 4 * log_std

log_hist.axvline(log_mean, color='r', lw=2, label='Mean')
log_hist.axvline(lower_bound, color='g', ls='--', lw=2, label='Lower Bound')
log_hist.axvline(upper_bound, color='g', ls='--', lw=2, label='Upper Bound')

log_hist.set_title('Логарифмическое распределение возраста')
plt.legend()

plt.tight_layout()
plt.show()

anomalies = df[(log_age < lower_bound) | (log_age > upper_bound)]
anomalies
# Out:
#             Ищет работу на должность: Последнее/нынешнее место работы  \
# 31137  Менеджер по работе с клиентами           ООО "ФёрстКэшКомпани"
# 32950                 Тестировщик игр                        OOO ЖМЫХ
# 33654            Frontend-разработчик                       Freelance
#
#          Последняя/нынешняя должность Обновление резюме        Авто  \
# 31137  Менеджер по работе с клиентами        2019-04-06  Не указано
# 32950                  Тестировщик ПО        2019-04-09  Не указано
# 33654            Frontend-разработчик        2019-04-19  Не указано
#
#                Образование Пол  Возраст  Опыт работы (месяц)            Город  \
# 31137              Среднее   М       15                  2.0  Санкт-Петербург
# 32950  Среднее специальное   М       15                  3.0           другие
# 33654  Среднее специальное   М      100                 30.0  Санкт-Петербург
#
#        ...  проектная работа  полная занятость  стажировка  волонтерство  \
# ...

# %% [markdown]
# ### Вывод по логарифмическому распределению:
#
# На графике видно, что логарифмическое распределение возраста соискателей близко к нормальному, с основной массой данных внутри пределов ±3 стандартных отклонений от среднего значения. Аномалиями можно считать возраст, выходящий за эти пределы, что составляет как крайне низкие (меньше 15 лет), так и необычно высокие значения (более 100 лет). Эти наблюдения требуют проверки на корректность, так как они могут быть результатом ошибок ввода данных.
